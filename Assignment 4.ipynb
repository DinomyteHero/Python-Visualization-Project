# %%
import pandas as pd

blue_df = pd.read_excel("Blue Bulls.xlsx", header = 1)
currie_df = pd.read_excel("Currie Cup table.xlsx", header = 1)

# %%
currie_df.dropna(inplace = True)

# %%
cc2020 = currie_df.tail(1)

# %%
pd.to_numeric(cc2020["Season"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-0096906a18d1> in <module>
# ----> 1 pd.to_numeric(cc2020["Season"], inplace = True)
#
# TypeError: to_numeric() got an unexpected keyword argument 'inplace'

# %%
currie_df["Season"] = pd.to_numeric(currie_df["Season"])

# %%
currie_df
# Out:
#     Season            Champions             Runner-Up     Score  \
# 19    1939            Transvaal      Western Province      17–6
# 20    1946   Northern Transvaal      Western Province      11–9
# 21    1947     Western Province             Transvaal     16–12
# 22    1950            Transvaal      Western Province     22–11
# 23    1952            Transvaal                Boland      11–9
# 24    1954     Western Province    Northern Transvaal      11–8
# 25    1956   Northern Transvaal                 Natal       9–8
# 29    1968   Northern Transvaal             Transvaal      16–3
# 30    1969   Northern Transvaal      Western Province     28–13
# 31    1970      Griqualand West    Northern Transvaal      11–9
# 33    1972            Transvaal     Eastern Transvaal     25–19
# 34    1973   Northern Transvaal            Free State     30–22
# 35    1974   Northern Transvaal             Transvaal     17–15
# 36    1975   Northern Transvaal            Free State      12–6
# ...

# %%
currie=pd.DataFrame()
currie[['Year','Champions', 'Losers']]=currie_df[['Season','Champions', 'Runner-Up']].copy()
currie['Year']=currie['Year'].astype(object)
currie['Champions']=currie['Champions'].astype(str)

# %%
currie
# Out:
#     Year            Champions                Losers
# 19  1939            Transvaal      Western Province
# 20  1946   Northern Transvaal      Western Province
# 21  1947     Western Province             Transvaal
# 22  1950            Transvaal      Western Province
# 23  1952            Transvaal                Boland
# 24  1954     Western Province    Northern Transvaal
# 25  1956   Northern Transvaal                 Natal
# 29  1968   Northern Transvaal             Transvaal
# 30  1969   Northern Transvaal      Western Province
# 31  1970      Griqualand West    Northern Transvaal
# 33  1972            Transvaal     Eastern Transvaal
# 34  1973   Northern Transvaal            Free State
# 35  1974   Northern Transvaal             Transvaal
# 36  1975   Northern Transvaal            Free State
# 37  1976           Free State      Western Province
# 38  1977   Northern Transvaal            Free State
# 39  1978   Northern Transvaal            Free State
# ...

# %%
currie_df1996 = (currie[currie["Year"] >= 1996])

# %%
def remove_n(list):
    pattern = '[0-9]'
    list = [re.sub(pattern, '', i) for i in list]
    return list

# %%
currie_df1996
# Out:
#     Year            Champions                Losers
# 57  1996              Sharks6         Golden Lions3
# 58  1997     Western Province  Free State Cheetahs4
# 59  1998          Blue Bulls5      Western Province
# 60  1999         Golden Lions                Sharks
# 61  2000     Western Province                Sharks
# 62  2001     Western Province                Sharks
# 63  2002           Blue Bulls          Golden Lions
# 64  2003           Blue Bulls                Sharks
# 65  2004           Blue Bulls   Free State Cheetahs
# 66  2005  Free State Cheetahs            Blue Bulls
# 68  2007  Free State Cheetahs          Golden Lions
# 69  2008               Sharks            Blue Bulls
# 70  2009           Blue Bulls   Free State Cheetahs
# 71  2010               Sharks      Western Province
# 72  2011         Golden Lions                Sharks
# 73  2012     Western Province                Sharks
# 74  2013               Sharks      Western Province
# ...

# %%
d_list = remove_n(currie_df1996["Champions"])

# %%
currie_df1996.reset_index(inplace = True)

# %%
currie_df1996["Champions"] = d_list
# Out:
# <ipython-input-136-ac9b938ab09d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   currie_df1996["Champions"] = d_list

# %%
currie_df1996["Losers"] = remove_n(currie_df1996["Losers"])
# Out:
# <ipython-input-138-090e721f9bf2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   currie_df1996["Losers"] = remove_n(currie_df1996["Losers"])

# %%
currie_df1996.drop(columns = ["Black Bulls", "Champtions"], inplace = True)
# Out:
# C:\Users\user-pc\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dff = currie_df1996[currie_df1996["Year"] == 1998]

# %%
str(currie_df1996["Champions"])
# Out:
# '0                  Sharks\n1        Western Province\n2              Blue Bulls\n3            Golden Lions\n4        Western Province\n5        Western Province\n6              Blue Bulls\n7              Blue Bulls\n8              Blue Bulls\n9     Free State Cheetahs\n10    Free State Cheetahs\n11                 Sharks\n12             Blue Bulls\n13                 Sharks\n14           Golden Lions\n15       Western Province\n16                 Sharks\n17       Western Province\n18           Golden Lions\n19    Free State Cheetahs\n20       Western Province\n21                 Sharks\n22    Free State Cheetahs\n23             Blue Bulls\nName: Champions, dtype: object'

# %%
currie_df1996['Champions'] = currie_df1996['Champions'].astype(str)
# Out:
# <ipython-input-166-48017341afb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   currie_df1996['Champions'] = currie_df1996['Champions'].astype(str)

# %%
bb_wincc = sum(currie_df1996["Champions"] == "Blue Bulls")

# %%
bb_losecc = sum(currie_df1996["Champions"] != "Blue Bulls")

# %%
bb_losecc
# Out:
# 18
